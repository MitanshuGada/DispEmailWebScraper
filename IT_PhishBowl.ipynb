# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
# from selenium.webdriver.support import expected_conditions as EC
import time
import pandas as pd
from collections import deque
import os

# %%
url='https://it.cornell.edu/phish-bowl'

# %%
options = webdriver.ChromeOptions()
# options.add_argument('--headless')
# browser = webdriver.Chrome(options=options)

# %%
df = pd.DataFrame(columns=['title', 'date_time', 'email_message'])

# %%
browser = webdriver.Chrome(options=options)
# emails_per_page = 15
# df = pd.dataFrame()
data = {'title': [],
        'date_time': [],
        'email_message': []}

browser.get(url)
for j in range(0, 13):
    print("Page: ",j)

    for i in range(1, 21):
        title = browser.find_element(By.CSS_SELECTOR, "tr:nth-child("+str(i)+") a").text
        browser.find_element(By.CSS_SELECTOR, "tr:nth-child("+str(i)+") a").click()
        date_time = browser.find_element(By.CSS_SELECTOR, "time").text
        # print(date_time)
        # print('-'*100)
        # print(browser.page_source)
        email_message = browser.find_element(By.CSS_SELECTOR, ".body-container-emails").get_attribute('innerHTML')
        # print(email_message)
        # print('-'*100)
        # print(browser.page_source)
        browser.back()
        print(title)
        data["date_time"].append(date_time)
        data['title'].append(title)
        data['email_message'].append(email_message)
    print('-'*100)
    browser.find_element(By.CSS_SELECTOR,".pager__item--next > a").click()
    # print(browser.page_source)

    # break
# Out:
# Page:  0
# Regarding Your Request for Account Closure
# Students Employment
# Baby grand piano donation
# Job
# STUDENT RESEARCH ASSISTANT POSITION
# CORRECTION OF ACCOUNT
# Disposal of welding and tools box
# Urgent Needed
# Subject varies: "Are you available now?", "Are you accessible now?", "Are you free now ?", "Available?", "Kindly provide me your available cell number"
# I RECORDED YOU!
# Job Opening
# Task: March 29th
# REMOTE INTERNSHIP
# Kindly provide your cell number that i can reach you at
# PAYROLL UPDATE !!!
# INDIVIDUAL ASSESSMENT REPORT
# Office Support_Desk: Restore Failed Deliveries
# STUDENT REMOTE ASSISTANT POSITION
# Subject varies: "Task: March 8th", "TASK: Friday March 8th", "Personnel Essential Welfare"
# Own A Snap-On Tools and Accessories
# ----------------------------------------------------------------------------------------------------
# Page:  1
# Regarding Your Request for Account Closure
# Hello [Name]
# Urgent Notice: COVID-19 Variant Case Identified contact tracing help needed.
# Immediate Action Required: COVID-19 Variant Contact Tracing Assistance
# Hi [First Name]
# UPDATE PAYCHECK ACCOUNT
# **Emergency: Help Needed for COVID-19 Variant Contact Tracing**
# Data Entry Representative At Cornell
# Time-Sensitive: Urgent Help Needed for COVID-19 Variant Contact Tracing
# ASSESSMENT REPORT FOR ALL STAFF MEMBERS 2024
# Update/Access Required Notice On March 4
# Career Progression Program
# Compliance Coordinator/Assistant Position
# Admin and Program Analyst Opening
# Re: Final Settlement Agreement Approved Today - #date1##
# PART/TIME ADMIN-ASSlSTANT OPPORTUNITY!!
# PR
# Job Offer
# Sign and Seal: Completed [#######-ber3.docx] Await Your Approval
# [Student Group Name or Abbreviation] Contact:
# ----------------------------------------------------------------------------------------------------
# Page:  2
# Employment Research
# Action Required: Review Recent Sign-in Activity
# Job Activity Notification
# Remote Research Assistant Opportunities at Cornell University
# EFT/ACH Payment Remittance Advice For Cornell (PAID IN FULL)
# **PAYCHECK**
# [Blank Subject]
# Are you available for a remote job
# [Employee Name]
# Grant Service!
# Essential Information About Your HealthEquity Account
# STUDENT PART TIME POSITION AVAILABLE
# Cornell University Review on New Checklist DD Update Document Distribution =gn&Return
# General Activate Cornell-Monday, Feb 05, 2024
# Cornell University - Research Assistants Needed
# Subject varies: "EARN $500 WEEKLY", "PART TIME JOB OFFER", "PERSONAL ASSISTANT JOB OFFER", "REMOTE ASSISTANT JOB OFFER"
# Request for Assistance
# Let me know
# Important Request Please_Complete_Document 20102S 20102S
# A Job Opportunity At Cornell University
# ----------------------------------------------------------------------------------------------------
# Page:  3
# Crucial DocShare: Your Signatory Required for [NetID] on Friday, February 9, 2024
# BILL AND MELINDA GATES FOUNDATION
# New voice message from [Name], on Monday January 29, 2024 [Time] [AM/PM] for mailbox [Number]
# Got a minute?
# INTERN REMOTE POSITION
# Opportunities Session Employment!!
# Cornell: MSecurity Access Expires Today 1/25/2024
# Subject varies: "Sibley School - Research Assistants Needed", "Opportunity for Research Assistants"
# Review and sign
# Document Completed: Complete viaSign # - [NetID]@cornell.edu
# New Phone Message
# Reference: (ETF/Remittance For [NetID]@cornell.edu Dated: Wednesday-January-2024 [Time] [AM/PM]) 'Ref:####'
# Re: [Recipient Name]
# Cornell | Default System Expire Today, [Time] [AM/PM],Tuesday, January 23, 2024
# Employee Benefits Program
# Subject varies: "Winter Session Employment!!", "Student Employment Research", "Winter Session Employment Research"
# Microsoft IT Support case ID: Email De-activation Request
# CORNELL UNIVERSITY
# Kindly get back to me ASAP. It's important
# Advanced Internship Opportunity
# ----------------------------------------------------------------------------------------------------
# Page:  4
# Cornell.edu:Delay- Service:Monday, January 29, 2024
# Available cellphone number?
# [Name]: Password Expiry Thursday, January 11, 2023
# DEPOSIT ACCOUNT CHANGE
# Signature Required: Cornell 2024 Employee Review
# Complete: Please review and sign your document ! Cornell
# Grant Service!
# STUDENT REMOTE RESEARCH ASSISTANT POSITION
# REMOTE INTERNSHIP PROGRAM
# Proposal for Research Assistant Position at Shaping
# Seasons Greetings...
# Item shared with you: "Notice - Unrecognized Log-In Detected - Your Online Account ID Disabled.pdf"
# EMPLOYMENT OFFER
# Job Opening For Research
# Re: Missing Payments
# Kindly get back to me ASAP. Its important
# New Message from Randy [Surname]
# Subject varies: "Part-Time Job Opening", "Research Project Available"
# STUDENT REMOTE RESEARCH POSITION
# EMERGENCY NOTICE: Changes to Employee Benefits Plan 2023/2024
# ----------------------------------------------------------------------------------------------------
# Page:  5
# CORNELL UNIVERSITY
# Reminder: Re-Autentication Notice for [user]@cornell.edu - (0) Days Left, Wednesday/December/2023 [time] [AM/PM]
# Cornell has a completed document
# About Piano
# CURRENT STATEMENT Howard [Surname]
# Subject varies: "Research Assistant Position Openings", "Research Assistant Opportunities for Students", "Graduate/Undergraduate Research Assistant Opportunities"
# TASK
# Complete: Please review and sign your document!
# [Cornell] Important Notification.
# EAP - Benefits Program
# ASSESSMENT REPORTS FOR ALL STAFFS
# Cornell University - Research Assistants Needed
# Are you free now ?
# 2023 Financial Benefit For Employees
# The Care Employment Opportunity
# Lucrative On/Off-Campus Opportunity for Cornell Students!
# important Update (netid)@cornell.edu
# GIVEAWAY-DOWNSIZING MUSICAL INSTRUNMENTS AND ITEMS
# New shared file 04/12/23
# Payment Complete and Confirmed
# ----------------------------------------------------------------------------------------------------
# Page:  6
# STUDENT REMOTE RESEARCH POSITION
# Urgent request
# Document Revised: [Number], -November 24, 2023
# Confirm ID Verification Report on Friday-November-2023 [Time] [AM/PM]
# INTERN POSITION
# Key Task
# Subject varies: "Job Opening For Research", "Research Assistance Needed"
# Cornell Dividend & Subsription Distribution
# Completed via Docshare: Please Sign Today Cornell_PrintScan_54260.pdf
# Please Review: Financial Statement #86782 || sent to "[NetID]@cornell.edu" from your organization
# Last Quarter JOB OFFER
# Completed with DocShare : Please Sign in EML Today | [NetID]@cornell.edu
# 2023 Employees Benefit Program
# Urgent respond!
# Final Reminder: Complete: [NetID] DocsOnline Docs Via E-Sign #38 - Cornell University Project-05(REVISED)
# TASK 1 (PRICE INQUIRY)
# Subject varies: "Cell Phone Number # Request", "Send me your available cell number"
# PAYCHECK
# BILL GATES FOUNDATION
# Student Research Assistant Needed
# ----------------------------------------------------------------------------------------------------
# Page:  7
# Are you free now ?
# Cornell |Re_Authenticationd Required| 17/Nov/2023
# Action Required: MFA/2FA Re-Authentication Notice Thursday 16 November, 2023
# Netid | lnbox Sync FaiIure | Thursday-November-2023 06:29 AM
# Heart-to-Heart International Job Offer
# A folder was shared with you - from Andy [Surname]
# 2023 Security Policy Standards
# New Employee Support Services!
# [Today@CU] - Pending Notification - 11/11/2023
# [SMS/Text] Bursar Office - Student Debt Payment Due
# PART/TIME ADMIN-ASSISTANT PLACEMENT.
# ALL CORNELL STUDENTS MUST ATTEND TO THIS IMMEDIATELY
# Your mailbox is 100% full
# [Employee Name]
# Reference: Remittance-Statement Note : Notifier For -[user]@cornell.edu On Nov 3rd 2023
# ***Verizon Wireless: You missed a call from (###) ### -3***, at [Time] [AM/PM] GmT
# DOWNSIZING MUSICAL INSTRUNMENTS AND ITEMS
# Research Assistant Opportunities at Cornell University
# MESSAGE FROM IT DEPARTMENT / CAMPUS INFORMATION HELPDESK OFFICE
# Modification of Payment Information
# ----------------------------------------------------------------------------------------------------
# Page:  8
# Invoice
# Modification of Payment Information
# [Spoofed Name] shared the folder "Company Payroll Amendment - taxsheet report 11/01/2023" with you
# Cornell-[REVIEW & SIGN] 2024 Benefit Open Enrollment Begins on October 30, 2023 at [Time] [AM/PM] for [Name]
# Attention please!!!
# Cornell-Approval Request for [Name] on October 28, 2023[Time] [AM/PM]
# 2023 Employees Benefit Program
# Research Assistant Needed
# ESSENTIAL TASK:
# RESEARCH ASSISTANTS JOB OPPORTUNITY
# Confirm ID Report Wednesday-October-2023 [Time] [AM/PM]
# Autumn Student Research Employment
# OPPORTUNITY TO OWN A WELDING TOOLS.
# [Employee Name]
# INTERN RESEARCH POSITION
# Dear [name or netid], kindly re-authenticate your 2FA settings | Sun, October 8, 2023
# Your mailbox is almost full.
# CHECKING UPDATE
# External: Cornell University SystemDesk Important Crediential Notification
# Essential Task
# ----------------------------------------------------------------------------------------------------

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                                                  title  \
# 0                          Available cellphone number?
# 1    [Name]: Password Expiry Thursday, January 11, ...
# 2                               DEPOSIT ACCOUNT CHANGE
# 3     Signature Required: Cornell 2024 Employee Review
# 4                                       Grant Service!
# ..                                                 ...
# 175                              STUDENT RESEARCH WORK
# 176     Sign Up for the Position of Research Assistant
# 177                                     IRM Pittington
# 178  New Password Notification Monday, March 13, 20...
# 179                        Admin Assistant/Coordinator
#
#                    date_time  \
# 0    Thu, 01/11/2024 - 12:00
# 1    Thu, 01/11/2024 - 12:00
# 2    Thu, 01/11/2024 - 12:00
# 3    Thu, 01/11/2024 - 12:00
# 4    Tue, 01/09/2024 - 12:00
# ..                       ...
# 175  Mon, 03/13/2023 - 12:00
# 176  Mon, 03/13/2023 - 12:00
# 177  Mon, 03/13/2023 - 12:00
# 178  Mon, 03/13/2023 - 12:00
# 179  Sat, 03/11/2023 - 12:00
#
#                                          email_message
# 0    <div class="accent-blue-green dialog dialog-no...
# 1    <div class="accent-blue-green dialog dialog-no...
# 2    <div class="accent-blue-green dialog dialog-no...
# 3    <div class="accent-blue-green dialog dialog-no...
# 4    <div class="accent-blue-green dialog dialog-no...
# ..                                                 ...
# 175  <p>\n\tCornell University College of Architect...
# 176  <p>\n\tDownload the Barcode below, Scan and fi...
# 177  <p>\n\tPlease sign and return the attached,pay...
# 178  <p>\n\t<span class="media media-element-contai...
# 179  <p>\n\tFrom: <strong>[NAME]</strong>&nbsp;\n\t...
#
# [180 rows x 3 columns]

# %%
df.shape
# Out:
# (180, 3)

# %%
df.to_csv('./cornell_phishbowl_data.csv')

# %%
file_path = './'
file_loc = 'temp.html'

with open(os.path.join(file_path, file_loc), 'w', encoding='utf-8') as file:
    file.write(email_message)

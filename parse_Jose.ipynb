# %%
# !pip install regex
# !pip install pandas

# %%
import pandas as pd
import regex as re

# %%
# file = open('./phishing 2022 jose_monkey.txt', 'r')

# %%
temp_email = """From jose@monkey.org Wed Jan 12 14:09:38 2022 +0000 Return-Path: MAILER-DAEMON Delivered-To: jose@monkey.org X-FDA: 79021818036.02.8B978AE Received: from out.smarshmail.com (out.smarshmail.com [199.193.206.151]) 	by imf04.b.hostedemail.com (Postfix) with ESMTP id AD63B100335B4 	for <jose@monkey.org>; Wed, 12 Jan 2022 14:09:37 +0000 (UTC) Received: from ggg.mqn1tzeu2jze1gwcnkzezpilvh.phxx.internal.cloudapp.net  (20.150.148.255) by MBX125-W8-CO-3.exch125.serverpod.net (10.224.13.216) with  Microsoft SMTP Server (version=TLS1_2,  cipher=TLS_ECDHE_RSA_WITH_AES_256_CBC_SHA384_P521) id 15.1.2375.17; Wed, 12  Jan 2022 06:09:35 -0800 Content-Type: multipart/alternative; boundary="===============1969536252==" MIME-Version: 1.0 Subject: Mail Delivery Failed: Returning Message to Sender To: <jose@monkey.org> From: Mail Delivery System Date: Wed, 12 Jan 2022 14:09:36 +0000 Message-ID: 	<5c0957de-31ab-4e99-bb2e-8fc53436eaca@MBX125-W8-CO-3.exch125.serverpod.net> X-Originating-IP: [20.150.148.255] X-ClientProxiedBy: MBX125-W7-CO-1.exch125.serverpod.net (10.224.13.200) To  MBX125-W8-CO-3.exch125.serverpod.net (10.224.13.216) X-Stat-Signature: 9wb7j61d5a6yf9o51p8co1fxshi6qqh7 Authentication-Results: imf04.b.hostedemail.com; 	dkim=none; 	dmarc=none; 	spf=none (imf04.b.hostedemail.com: domain of out.smarshmail.com has no SPF policy when checking 199.193.206.151) smtp.helo=out.smarshmail.com X-Spam-Status: No, score=3.20 X-Rspamd-Server: rspam09 X-Rspamd-Queue-Id: AD63B100335B4 X-HE-Tag: 1641996577-429838 Status: RO X-Status:  X-Keywords:                  X-UID: 1  --===============1969536252=Content-Type: text/plain; charset="iso-8859-1" MIME-Version: 1.0 Content-Transfer-Encoding: quoted-printable Content-Description: Mail message body    Microsoft Failure Delivery Notice.   User: jose@monkey.org   3 pending sent messages couldn't be delivered     Action Required.     How to Fix It.  Click here to view undelivered sent email.   Created Date: 01. 12. 2022       The information contained in or attached to this communication is intended solely for the use of the individual or entity to whom it is addressed and others authorised to receive it. It may contain confidential or legally privileged information. If you are not the intended recipient you are hereby notified that any disclosure, copying, distribution or taking any action in reliance on the contents of this information is strictly prohibited and may be unlawful. If you have received this communication in error, please notify me immediately by responding to this email and then delete it from your system. We are neither liable for the proper and complete transmission of the information contained in this communication nor for any delay in its receipt.    =20 --===============1969536252=Content-Type: text/html; charset="iso-8859-1" MIME-Version: 1.0 Content-Transfer-Encoding: quoted-printable Content-Description: Mail message body  <HTML><head><meta http-equiv=3D"Content-Type" content=3D"text/html; charset=3Diso-8859-1"/></head><BODY><DIV id=3D:470 class=3D"Ar Au Ao" style=3D"DISPLAY: block"> <DIV spellcheck=3Dfalse role=3Dtextbox tabIndex=3D1 aria-label=3D"Message Body" aria-multiline=3Dtrue id=3D:46w class=3D"Am Al editable LW-avf tS-tW tS-tY" hideFocus contentEditable=3Dtrue style=3D"DIRECTION: ltr; MIN-HEIGHT: 355px" g_editable=3D"true"> <P><STRONG>Microsoft Failure Delivery Notice.</STRONG></P> <DIV> <DIV style=3D"BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; VERTICAL-ALIGN: baseline; BORDER-BOTTOM-WIDTH: 0px; COLOR: rgb(32,31,30); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; PADDING-LEFT: 0px; MARGIN: 0px; PADDING-RIGHT: 0px; BORDER-TOP-WIDTH: 0px">User:&nbsp;<STRONG>jose@monkey.org</STRONG></DIV> <DIV style=3D"BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; VERTICAL-ALIGN: baseline; BORDER-BOTTOM-WIDTH: 0px; COLOR: rgb(32,31,30); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; PADDING-LEFT: 0px; MARGIN: 0px; PADDING-RIGHT: 0px; BORDER-TOP-WIDTH: 0px"><BR></DIV> <P style=3D"COLOR: rgb(32,31,30)">3 pending sent messages couldn't be delivered&nbsp;</P> <DIV style=3D"BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; VERTICAL-ALIGN: baseline; BORDER-BOTTOM-WIDTH: 0px; COLOR: rgb(32,31,30); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; PADDING-LEFT: 0px; MARGIN: 0px; PADDING-RIGHT: 0px; BORDER-TOP-WIDTH: 0px"><BR></DIV> <DIV style=3D"BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; VERTICAL-ALIGN: baseline; BORDER-BOTTOM-WIDTH: 0px; COLOR: rgb(32,31,30); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; PADDING-LEFT: 0px; MARGIN: 0px; PADDING-RIGHT: 0px; BORDER-TOP-WIDTH: 0px">Action Required.&nbsp; &nbsp;&nbsp;<BR>How to Fix It. <DIV style=3D"BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; VERTICAL-ALIGN: baseline; BORDER-BOTTOM-WIDTH: 0px; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; PADDING-LEFT: 0px; MARGIN: 0px; PADDING-RIGHT: 0px; BORDER-TOP-WIDTH: 0px"><BR><STRONG><SPAN style=3D"COLOR: rgb(0,0,255)"><A href=3D"https://tuwa.org.tw/%3C%3E/NewestUpdate/?email=3Djose@monkey.org" target=3D_blank data-saferedirecturl=3D"https://www.google.com/url?q=3Dhttps://joetradeco.com/%253C%253E/Growth/?email%3D25&amp;source=3Dgmail&amp;ust=3D1642003348399000&amp;usg=3DAOvVaw1wYDTjNo9lrH-JO9asK0O5">Click here</A></SPAN>&nbsp;</STRONG>to view undelivered sent email.</DIV> <DIV style=3D"BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; VERTICAL-ALIGN: baseline; BORDER-BOTTOM-WIDTH: 0px; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; PADDING-LEFT: 0px; MARGIN: 0px; PADDING-RIGHT: 0px; BORDER-TOP-WIDTH: 0px"><BR></DIV> <DIV style=3D"BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; VERTICAL-ALIGN: baseline; BORDER-BOTTOM-WIDTH: 0px; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; PADDING-LEFT: 0px; MARGIN: 0px; PADDING-RIGHT: 0px; BORDER-TOP-WIDTH: 0px">Created Date: 01. 12. 2022</DIV></DIV></DIV> <DIV><BR></DIV> <DIV><BR></DIV> <DIV><BR></DIV> <DIV><SPAN style=3D"LINE-HEIGHT: 18px"><FONT size=3D1><FONT color=3D#999999>The information contained in or attached to this communication is intended solely for the use of the individual or entity to whom it is addressed and others authorised to receive it. It may contain confidential or legally privileged information. If you are not the intended recipient you are hereby notified that any disclosure, copying, distribution or taking any action in reliance on the contents of this information is strictly prohibited and may be unlawful. If you have received this communication in error, please notify me immediately by responding to this email and then delete it from your system. We are neither liable for the proper and complete transmission of the information contained in this communication nor for any delay in its receipt.&nbsp;</FONT>&nbsp; &nbsp;&nbsp;</FONT></SPAN></DIV></DIV></DIV></BODY></HTML> --===============1969536252==-- """

# %%
temp_email
# Out:
# 'From jose@monkey.org Wed Jan 12 14:09:38 2022 +0000 Return-Path: MAILER-DAEMON Delivered-To: jose@monkey.org X-FDA: 79021818036.02.8B978AE Received: from out.smarshmail.com (out.smarshmail.com [199.193.206.151]) \tby imf04.b.hostedemail.com (Postfix) with ESMTP id AD63B100335B4 \tfor <jose@monkey.org>; Wed, 12 Jan 2022 14:09:37 +0000 (UTC) Received: from ggg.mqn1tzeu2jze1gwcnkzezpilvh.phxx.internal.cloudapp.net  (20.150.148.255) by MBX125-W8-CO-3.exch125.serverpod.net (10.224.13.216) with  Microsoft SMTP Server (version=TLS1_2,  cipher=TLS_ECDHE_RSA_WITH_AES_256_CBC_SHA384_P521) id 15.1.2375.17; Wed, 12  Jan 2022 06:09:35 -0800 Content-Type: multipart/alternative; boundary="===============1969536252==" MIME-Version: 1.0 Subject: Mail Delivery Failed: Returning Message to Sender To: <jose@monkey.org> From: Mail Delivery System Date: Wed, 12 Jan 2022 14:09:36 +0000 Message-ID: \t<5c0957de-31ab-4e99-bb2e-8fc53436eaca@MBX125-W8-CO-3.exch125.serverpod.net> X-Originating-IP: [20.150.148.2
# ...

# %%
single_email = {'from': "", 
              'subject': "",
              'date': "",
              'to': "",
              'text_plain': "",
              'text_html': ""
            }
email_dict = {}

# %%
def extractInfo(email, boundary):
    # data_from = re.findall('(?<=From: )(.+)(?=Date: )', email)
    # data_subject = re.findall('(?<=Subject: )(.+)(?=To:)', email)
    # data_date = re.findall('(?<=Date: )(.+)(?=Message)', email)
    # data_to = re.findall('(?<=To: )(.+)(?=From)', email)
    # # boundary = re.findall('(?<=boundary=")(.+)(?=")', email)
    
    regex_html = re.findall(f'(?<=Content-Type: text\/html;)(.*?)(?=--{boundary})', email)
    regex_plain = re.findall(f'(?<=Content-Type: text\/plain;)(.*?)(?=--{boundary})', email)

    # print(data_from)
    # print(data_subject)
    # print(data_to)
    # print(data_date)
    # print(boundary)
    print(f"regex_html: {regex_html}")

    print(f"regex_plain: {regex_plain}")

    if regex_plain != []:
        text_plain = regex_plain[0]
    else:
        text_plain = ""

    if regex_html != []:
        text_html = regex_html[0]
    else:
        text_html = ""


    return (text_plain, text_html)

# %%
with open('./phishing 2022 jose_monkey.txt', 'r') as file:
# with open('./temp.txt', 'r') as file:
    one_mail = ""
    i = 0
    boundary = ""
    while(True):
    # for i in range(141):
        # boundary = ""
        line = file.readline()
        one_mail+=line
        # print(line)
        # remove \n    
        one_mail = one_mail[:-1]

        # remove '=' from the end of line if there is an =
        if (one_mail[-1:] == "=" and one_mail[-2:] != "==" ):
            one_mail = one_mail[:-1]
        else:
            one_mail += " "

        checkBoundary = re.findall('(boundary)', line)
        # print(checkBoundary)
        # flag = False
        # print(checkBoundary)
        if checkBoundary != []:
            # print("in")
            # flag = True
            print(f"1: {checkBoundary}")
            print(f"1: {line}")
            checkBoundary = re.findall('(?<=boundary=")(.+)(?=")', line)
            if checkBoundary == []:
                print(f"2: {line}")
                checkBoundary = re.findall(f'?<=boundary=)(.+)', line)
                if checkBoundary != []:
                    print(f"2: {checkBoundary}")
                    boundary = checkBoundary[0]
            else:
                boundary = checkBoundary[0]
            
        data_from = re.findall('(?<=^From: )(.+)(?=\n)', line)
        if data_from != []:
            # print(data_from)
            single_email["from"] = data_from[0]
            data_from = []

        data_subject = re.findall('(?<=^Subject: )(.+)(?=\n)', line)
        if data_subject != []:
            # print(data_subject)
            single_email["subject"] = data_subject[0]
            data_subject = []

        data_date = re.findall('(?<=^Date: )(.+)(?=\n)', line)
        if data_date != []:
            # print(f"date: {data_date}")
            single_email["date"] = data_date[0]
            data_date = []
                
        data_to = re.findall('(?<=^To: )(.+)(?=\n)', line)
        if data_to != []:
            # print(data_to)
            single_email["to"] = data_to[0]
            data_to = []
        
        # print(data_from)
        # print(data_subject)
        # print(data_to)
        # print(data_date)

        # if flag:
        # if boundary != "":
        #     print(boundary)
        #     print(line)
        #     break        
        if one_mail[-3:-1] == '--':
            print(len(one_mail))
            # extractInfo(one_mail)
            print(one_mail)
            print(type(one_mail))
            print(f"boundary: {boundary}")
            single_email["text_plain"], single_email["text_html"] = extractInfo(one_mail, boundary)
            one_mail = ""
            boundary = ""
            i+=1
            print(i)
            print('-'*100)
            
            # save 
            email_dict[i] = single_email
            
        elif boundary == "" and one_mail[-8:-1] == "</html>":
            print(len(one_mail))
            # extractInfo(one_mail)
            print(one_mail)
            print(type(one_mail))
            print(f"boundary: {boundary}")
            single_email["text_plain"], single_email["text_html"] = extractInfo(one_mail, boundary)
            one_mail = ""
            boundary = ""
            i+=1
            print(i)
            print('-'*100)
            
            # save 
            email_dict[i] = single_email

        # print(one_mail[-7:-1])

    # print(data_from)
    # print(data_subject)
    # print(data_to)
    # print(data_date)
    print(email_dict)
    print(one_mail)
# Out:
# 1: ['boundary']
# 1: Content-Type: multipart/alternative; boundary="===============1969536252=="
#
# 6765
# ...

# %%
df = pd.DataFrame(email_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df = pd.DataFrame(email_dict)
#
# File ~/Desktop/2023-2024/OSU/phishing Zane, Michelle/DispEmailWebScraper/env/lib/python3.9/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...

# %%
one_mail[-1:]
# Out:
# '\n'

# %%
re.findall('(?<=From: )(.+)', x)
# Out:
# ['Mail Delivery System',
#  'Mail Delivery System',
#  '"Mail Delivery System(s)"',
#  'Mail Delivery System',
#  'Mail Delivery System',
#  '1-888-345-0234',
#  ' 1-888-345-0234',
#  '"+1  (501)"',
#  ' 1-888-345-0234',
#  '"monkey.org" <info@cshauxun.com>',
#  '"Charles Schwab" <mayra.parrales@hgj.gob.ec>',
#  '"Charles Schwab" <mayra.parrales@hgj.gob.ec>',
#  'Mail Delivery System',
#  'sales@g-dys.info',
#  '"Email Service" <info@sketchstwenty3.com>',
#  '"Amazon.co.jp" <arnazom@lptaoyou.cn>',
#  '"WeTransfer" <postmaster@octfirr.xyz>',
#  '"WeTransfer" <postmaster@octfirr.xyz>',
#  'monkey.org  <cargo_notice@mail.evergreen-line.com>',
#  '"Mail-Admin monkey.org" <jose@karansolutions.com>',
#  '"Mail-Admin monkey.org" <jose@karansolutions.com>',
#  'Service Updates <info@geek-squadservices80.co>',
#  'monkey.org PORTAL-IT <appleid@id.apple.com>',
#  'WellsFargo Online <williamcody@carteramirxxdeal.com>',
#  'monkey.org  <smtpfox-8szi3@sucrammusic.com>',
# ...
